# %%
import tensorflow as tf
from tensorflow.keras import  Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Input, Flatten, Dense

# %%
# Define a model architecture
model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(), 
    Dense(128, activation='relu'), 
    Dense(10, activation='softmax')
])
# Out:
# I0000 00:00:1781132350.431695   93153 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1766 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Load and preprocess teh MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape((-1, 28, 28, 1)).astype('float32') / 255.0
x_test = x_test.reshape((-1, 28, 28, 1)).astype('float32') / 255.0

# %%
# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/10
# I0000 00:00:1781132600.221382   93513 service.cc:153] XLA service 0x7f90b4001ad0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781132600.221427   93513 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2050, Compute Capability 8.6 (Driver: 13.1.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.23.0)
# I0000 00:00:1781132600.322812   93513 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781132600.809669   93513 cuda_dnn.cc:461] Loaded cuDNN version 92300
# I0000 00:00:1781132600.849610   93513 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1570__.30
#    3/1500 ━━━━━━━━━━━━━━━━━━━━ 46s 31ms/step - accuracy: 0.1198 - loss: 2.3247
# I0000 00:00:1781132608.627370   93513 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 13ms/step - accuracy: 0.9515 - loss: 0.1620 - val_accuracy: 0.9823 - val_loss: 0.0590
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9840 - loss: 0.0510 - val_accuracy: 0.9847 - val_loss: 0.0496
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9884 - loss: 0.0354 - val_accuracy: 0.9893 - val_loss: 0.0386
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9915 - loss: 0.0254 - val_accuracy: 0.9887 - val_loss: 0.0393
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9938 - loss: 0.0193 - val_accuracy: 0.9899 - val_loss: 0.0380
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9950 - loss: 0.0157 - val_accuracy: 0.9882 - val_loss: 0.0426
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9958 - loss: 0.0128 - val_accuracy: 0.9886 - val_loss: 0.0409
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9965 - loss: 0.0101 - val_accuracy: 0.9903 - val_loss: 0.0430
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9974 - loss: 0.0083 - val_accuracy: 0.9863 - val_loss: 0.0597
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.9890 - val_loss: 0.0518
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9895 - loss: 0.0398
# Test Loss: 0.03975192457437515
# Test Accuracy: 0.9894999861717224
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step

# %%
# Make predictions
predictions = model.predict(x_train)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step
