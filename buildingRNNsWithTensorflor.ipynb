# %%
# import necessary libraries 
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense

# %%
# Define the model architecture (eg simple rnn)
model = Sequential([
    SimpleRNN(64, input_shape=(sequence_length, input_dim), activation='relu'), 
    Dense(num_classes, activation='softmax')
])

# %%
# Define the model architecture (eg lstm)
model = Sequential([
    LSTM(64, input_shape=(sequence_length, input_dim)), 
    Dense(num_classes, activation='softmax')
])

# %%
# Define the model architecture (eg GRU)
model = Sequential([
    GRU(64, input_shape=(sequence_length, input_dim), activation='relu'), 
    Dense(num_classes, activation='softmax')
])

# %%
# compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Load and preprocess data
X_train, y_train = load_data(test_data_path)
X_test, y_test = load_data(test_data_path)

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# %%
# Save entire model to HDF5 file
model.save('model.h5')

# %%
# Save model architecture to JSON file
with open('model.json', 'w') as json_file:
    json_file.write(model.to_json())

# Save model weights to HDF5 file
model.save_weights('model_weights.h5')

# %%
# Load entire model
from tensorflow.keras.models import load_model

loaded_model = load_model('model.h5')

# %%
 # Load model architecture and weights separately
from tensorflow.keras.models import model_from_json

with open('model.json', 'r') as json_file:
    loaded_model_json = json_file.read()
loaded_model - model_from_json(loaded_model_json)

loaded_model.load_weights('models_weights.h5')
